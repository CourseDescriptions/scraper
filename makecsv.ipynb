# %%
import json
import os
import pandas as pd

# Define the directory containing the JSON files
directory = "data/"

# Dictionary to track the most recent file for each school
latest_files = {}
# Process each JSON file
for root, _, files in os.walk(directory):
    for file in files:
        if file.endswith(".json"):
            filepath = os.path.join(root, file)
            school_name = os.path.basename(root)  # Extract school name from folder
            timestamp = file.replace(".json", "")  # Extract timestamp from filename
            
            # Update the latest file for each school
            if school_name not in latest_files or timestamp > latest_files[school_name]["timestamp"]:
                latest_files[school_name] = {"timestamp": timestamp, "filepath": filepath}

allCourses = []
# Process only the most recent files
for entry in latest_files.values():
    filepath = entry["filepath"]
    print(filepath)
    with open(filepath, "r", encoding="utf-8") as file:
        try:
            data = json.load(file)  # Load JSON data
            allCourses.extend(data)
        except json.JSONDecodeError as e:
            print(f"Error reading {filepath}: {e}")

df = pd.DataFrame(allCourses)
df.head(15)
# Out:
# data/UC_Merced/2025_04_02-11_16_30_PM.json
# data/UC_Davis/2025_04_02-11_15_35_PM.json
# data/San_Jose_State/2025_04_03-12_00_57_PM.json
# data/CSU_Long_Beach/2025_04_03-11_51_15_AM.json
# data/Stanislaus_State/2025_04_03-11_21_45_AM.json
# data/CSU_San_Marcos/2025_04_03-11_34_20_AM.json
# data/CSU_Fullerton/2025_04_03-10_40_05_AM.json
# data/Cal_Poly_San_Luis_Obispo/2025_04_03-10_43_54_AM.json
# data/Cal_Poly_Pomona/2025_04_03-11_53_23_AM.json
# data/Cal_Maritime/2025_04_03-10_44_22_AM.json
# data/San_Diego_State/2025_04_03-11_53_40_AM.json
# data/UC_San_Diego/2025_04_02-11_17_36_PM.json
# data/UC_Irvine/2025_04_02-11_15_49_PM.json
# data/UC_Santa_Cruz/2025_04_02-11_18_44_PM.json
# data/UC_Santa_Barbra/2025_04_02-11_16_45_PM.json
# data/CSU_Chico/2025_04_03-10_39_33_AM.json
# data/CSU_Monterey_Bay/2025_04_03-11_15_13_AM.json
# data/CSU_Bakersfield/2025_04_03-10_38_35_AM.json
# data/Fresno_State/2025_04_03-11_45_43_AM.json
# data/UCLA/2025_04_02-11_15_54_PM.json
# data/UC_San_Francisco/2025_04_02-11_17_48_PM.json
# data/CSU_San_Bernadino/2025_04_03-10_42_37_AM.json
# data/Cal_Poly_Humboldt/2025_04_03-11_19_48_AM.json
# data/UC_Berkeley/2025_04_02-11_15_34_PM.json
# data/CSU_East_Bay/2025_04_03-11_22_07_AM.json
# data/CSU_Dominguez_Hills/2025_04_03-10_39_33_AM.json
#         code                                            title  \
# 0     AE 171               Aerospace Structures and Materials
# 1     AE 172                      Flight Dynamics and Control
# 2     AE 173                             Aerospace Propulsion
# 3     AE 174                                   Aeroelasticity
# 4   ANTH 001       Introduction to Sociocultural Anthropology
# 5   ANTH 003      Introduction to Anthropological Archaeology
# 6   ANTH 005          Introduction to Biological Anthropology
# 7   ANTH 010             Quantitative Methods in Anthropology
# 8   ANTH 092                       Internship in Anthropology
# 9   ANTH 095            Lower Division Undergraduate Research
# 10  ANTH 098              Lower Division Directed Group Study
# 11  ANTH 099                  Lower Division Individual Study
# 12  ANTH 100  History of Anthropological Thought and Practice
# 13  ANTH 110  Migration, Diaspora and Transnational Belonging
# 14  ANTH 111                The Anthropology of Globalization
#
#                                           description  \
# 0   Builds on the background learned in Statics an...
# 1   Introduces flight dynamics, modeling and funda...
# 2   Provides an overview of relevant fundamentals ...
# 3   Overview of fundamental Fluid-Structure Intera...
# 4   Introduction to human culture and cultural div...
# 5   Survey of theory, field and analysis methods, ...
# 6   Introduction to evolution and how natural sele...
# 7   Introduces students to quantitative methods us...
# 8   Provides oversight and structure for a student...
# 9                                Supervised research.
# 10
# 11
# 12  Historical overview of key individuals and cen...
# 13  Exploration of modern, global movements of peo...
# 14  Introduces anthropological approaches to the p...
#
#                                                   url  school_id
# 0   https://catalog.ucmerced.edu/preview_course_no...          4
# 1   https://catalog.ucmerced.edu/preview_course_no...          4
# 2   https://catalog.ucmerced.edu/preview_course_no...          4
# 3   https://catalog.ucmerced.edu/preview_course_no...          4
# 4   https://catalog.ucmerced.edu/preview_course_no...          4
# 5   https://catalog.ucmerced.edu/preview_course_no...          4
# 6   https://catalog.ucmerced.edu/preview_course_no...          4
# 7   https://catalog.ucmerced.edu/preview_course_no...          4
# 8   https://catalog.ucmerced.edu/preview_course_no...          4
# 9   https://catalog.ucmerced.edu/preview_course_no...          4
# 10  https://catalog.ucmerced.edu/preview_course_no...          4
# 11  https://catalog.ucmerced.edu/preview_course_no...          4
# 12  https://catalog.ucmerced.edu/preview_course_no...          4
# 13  https://catalog.ucmerced.edu/preview_course_no...          4
# 14  https://catalog.ucmerced.edu/preview_course_no...          4

# %%
df.to_csv("uc_calstate_data.csv")
